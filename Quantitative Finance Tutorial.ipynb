# %% [markdown]
# # Link
# https://www.youtube.com/watch?v=OUNXFU7xuCc&list=PLo9Vi5B84_dc-zFPjeXdxCaawQiwEW60x&index=1

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start_date = '2003-01-01'
end_date = '2023-06-01'

# %%
#Downloading the data 
ticker = 'SPY'
df = yf.download(ticker,start_date,end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2003-01-02  88.849998  91.300003  88.540001  91.070000  61.811775  44516300
# 2003-01-03  90.910004  91.379997  90.500000  91.349998  62.001823  32222600
# 2003-01-06  91.239998  93.489998  91.169998  92.959999  63.094555  40984500
# 2003-01-07  92.900002  93.370003  92.199997  92.730003  62.938465  38640400
# 2003-01-08  92.199997  92.400002  91.050003  91.389999  62.028965  38702200

# %%
df.shape
# Out:
# (5138, 6)

# %%
msft = yf.Ticker("MSFT")

# get all stock info
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'fax': '425 706 7329',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'industryDisp': 'Software—Infrastructure',
#  'sector': 'Technology',
# ...

# %%
amz = yf.Ticker("AMZN")
amz.info
# Out:
# {'address1': '410 Terry Avenue North',
#  'city': 'Seattle',
#  'state': 'WA',
#  'zip': '98109-5210',
#  'country': 'United States',
#  'phone': '206 266 1000',
#  'website': 'https://www.aboutamazon.com',
#  'industry': 'Internet Retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
# ...

# %%
goog = yf.Ticker("GOOG")
goog.info
# Out:
# {'address1': '1600 Amphitheatre Parkway',
#  'city': 'Mountain View',
#  'state': 'CA',
#  'zip': '94043',
#  'country': 'United States',
#  'phone': '650 253 0000',
#  'website': 'https://www.abc.xyz',
#  'industry': 'Internet Content & Information',
#  'industryDisp': 'Internet Content & Information',
#  'sector': 'Communication Services',
# ...

# %%
#Downloading multiple figures
tickers = ['SPY']
df = yf.download(tickers,start_date,end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5138 entries, 2003-01-02 to 2023-05-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5138 non-null   float64
#  1   High       5138 non-null   float64
#  2   Low        5138 non-null   float64
#  3   Close      5138 non-null   float64
#  4   Adj Close  5138 non-null   float64
#  5   Volume     5138 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 281.0 KB

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2003-01-02  88.849998  91.300003  88.540001  91.070000  61.811787  44516300
# 2003-01-03  90.910004  91.379997  90.500000  91.349998  62.001808  32222600
# 2003-01-06  91.239998  93.489998  91.169998  92.959999  63.094601  40984500
# 2003-01-07  92.900002  93.370003  92.199997  92.730003  62.938484  38640400
# 2003-01-08  92.199997  92.400002  91.050003  91.389999  62.028965  38702200

# %%
#Converting our index to date
df.index = df.index.date
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2003-01-02  88.849998  91.300003  88.540001  91.070000  61.811787  44516300
# 2003-01-03  90.910004  91.379997  90.500000  91.349998  62.001808  32222600
# 2003-01-06  91.239998  93.489998  91.169998  92.959999  63.094601  40984500
# 2003-01-07  92.900002  93.370003  92.199997  92.730003  62.938484  38640400
# 2003-01-08  92.199997  92.400002  91.050003  91.389999  62.028965  38702200

# %% [markdown]
# ## Calculating daily returns

# %%
df['R'] = df['Adj Close'].pct_change()
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# 2003-01-02  88.849998  91.300003  88.540001  91.070000  61.811787  44516300
# 2003-01-03  90.910004  91.379997  90.500000  91.349998  62.001808  32222600
# 2003-01-06  91.239998  93.489998  91.169998  92.959999  63.094601  40984500
# 2003-01-07  92.900002  93.370003  92.199997  92.730003  62.938484  38640400
# 2003-01-08  92.199997  92.400002  91.050003  91.389999  62.028965  38702200
#
#                    R
# 2003-01-02       NaN
# 2003-01-03  0.003074
# 2003-01-06  0.017625
# 2003-01-07 -0.002474
# 2003-01-08 -0.014451

# %%
yf.download(tickers = "SPY AAPL",  # list of tickers
            period = "1y",         # time period
            interval = "1d",       # trading interval
            prepost = False,       # download pre/post market hours data?
            repair = True)
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2022-06-07  147.827286  408.813660  148.710007  415.739990  149.000000
# 2022-06-08  147.081741  404.368958  147.960007  411.220001  149.869995
# 2022-06-09  141.793320  394.751923  142.639999  401.440002  147.949997
# 2022-06-10  136.316040  383.305817  137.130005  389.799988  140.759995
# 2022-06-13  131.097198  368.752411  131.880005  375.000000  135.199997
# ...                ...         ...         ...         ...         ...
# 2023-06-01  180.089996  421.820007  180.089996  421.820007  180.119995
# 2023-06-02  180.949997  427.920013  180.949997  427.920013  181.779999
# 2023-06-05  179.580002  427.100006  179.580002  427.100006  184.949997
# 2023-06-06  179.210007  428.029999  179.210007  428.029999  180.119995
# ...
